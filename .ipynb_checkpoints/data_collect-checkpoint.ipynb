# %% [markdown]
# BWM 320i<br/>
# env: phd<br/>
# aim: handle data as (x0,u,x1)
# - x0: init 7-dim car state<br/>
# - u:  input 2-dim(v-delta,a)<br/>
# - x1: next 7-dim car state<br/>

# %%
from scipy.integrate import odeint
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import title, legend
import math

from scipy.integrate import solve_ivp

from vehiclemodels.parameters_vehicle2 import parameters_vehicle2
from vehiclemodels.init_st import init_st
from vehiclemodels.vehicle_dynamics_st import vehicle_dynamics_st

# %%
p = parameters_vehicle2()

# %%
def cal_x1(t,x,uInit):
    f = vehicle_dynamics_st(x,uInit,p)
    return f

# %%
def cal_vehicle_dynamic(x,u):
    t_span = (0,0.1)
    x_new_st = solve_ivp(fun=lambda t,y:cal_x1(t,y,u),t_span=t_span,y0=x)
    x_new = [x_new_st.y[0][-1],x_new_st.y[1][-1],x_new_st.y[2][-1],x_new_st.y[3][-1],x_new_st.y[4][-1],x_new_st.y[5][-1],x_new_st.y[6][-1]]
    return x_new

# %%
x = [0,1.5,0,15,0,0,0]
u = [0.15,1]

# %%
# n: repeat time
def write_data(x0,u,n):
    data = []
    x_init = x0
    for i in range(n):
        x_next = cal_vehicle_dynamic(x_init,u)
        data.append([x_init,u,x_next])
        
        x_init = x_next
    print("-------")
    print(len(data),len(data[0]),len(data[0][0]))
    # with open("data.txt","w") as f:
    #     for j in data:
    #         f.writelines(str(j)+"\n")
write_data(x,u,15)
# Out:
# -------
# 15 3 7

# %%
n = 100
def draw_test(x0,u,n):
    x_data = [x0[0]]
    y_data = [x0[1]]
    x_init = x0
    for i in range(n):
        x_next = cal_vehicle_dynamic(x_init,u)
        x_data.append(x_next[0])
        y_data.append(x_next[1])
        x_init = x_next
    x_np = np.array(x_data)
    y_np = np.array(y_data)
    plt.scatter(x_np,y_np)
    print(x_np)
    plt.plot(x_np,y_np)
    
draw_test(x,u,n)
# Out:
# [ 0.          1.50499717  3.01992691  4.54448037  6.07782261  7.61824354
#   9.16278196 10.70683584 12.2437652  13.76449873 15.25716333 16.70676337
#  18.0949458  19.39989674 20.59642485 21.65629508 22.54888155 23.24220855
#  23.70444025 23.90586041 23.82134925 23.43331267 22.73494867 21.7336458
#  20.45420482 18.94146503 17.26181691 15.50301434 13.7716906  12.18806586
#  10.87754005  9.9592192   9.5319297   9.65890865 10.35305198 11.56523751
#  13.17864831 15.01200184 16.83393952 18.38940495 19.43662468 19.79049788
#  19.36526671 18.20701441 16.50575119 14.57851378 12.81961215 11.62178767
#  11.28144051 11.90991424 13.37786972 15.31770596 17.19762578 18.46077693
#  18.69816405 17.80274325 16.04433181 14.0191321  12.46584695 11.9942391
#  12.82221842 14.63868826 16.68065696 18.03181794 18.04078074 16.67040606
#  14.58143894 12.85440282 12.43853833 13.59830002 15.69012645 17.46721291
#  17.80949845 16.47065879 14.30556351 12.74952112 12.86255703 14.5872171
#  16.75515203 17.86864179 17.13875461 15.05816278 13.08430906 12.62448471
#  14.02483835 16.29442721 17.7932204  17.41666552 15.42216403 13.27071582
#  12.56529654 13.85045274 16.17598581 17.78478625 17.43884873 15.38455337
#  13.19570072 12.57671869 14.02866796 16.42679054 17.87720849]

# %%
# 3组 7维数组
# matrix = np.random.random(size=[3,7,1])
def gauss_noise_matrix(matrix,sigma,mu):
    channel_size = len(matrix)
    height = len(matrix[0])
    width = len(matrix[0][0])
    noise_matrix = np.random.normal(mu,sigma,size=[channel_size,height,width]).astype(np.float32)
    print(noise_matrix[0][0])
    
    matrix += noise_matrix
    print(">>>added gaussain noise")

# %%
np.random.random(size=[10,3,7])
# Out:
# array([[[4.99304078e-01, 6.26703924e-01, 8.46619795e-01, 9.33979999e-01,
#          8.08054216e-01, 6.86319629e-01, 8.41459247e-01],
#         [5.44268048e-01, 1.34271863e-02, 2.10540788e-02, 5.69238228e-01,
#          7.81531059e-01, 1.14454037e-01, 4.73946211e-01],
#         [8.94029398e-01, 1.32271465e-01, 5.84472596e-02, 8.17103304e-01,
#          9.57133404e-01, 3.49672180e-03, 4.45354157e-01]],
#
#        [[8.36048363e-01, 3.71752694e-01, 2.34437293e-01, 4.81199715e-01,
#          9.92700065e-01, 6.70469979e-01, 9.39463697e-01],
#         [4.98304227e-02, 8.81306179e-01, 3.04451535e-01, 4.23755100e-01,
#          9.56284030e-01, 3.07748911e-01, 7.33925439e-01],
#         [5.54119598e-01, 4.10432532e-01, 5.43805390e-01, 5.57227709e-01,
#          7.62622365e-01, 2.32106639e-01, 2.38393452e-01]],
#
#        [[6.88057419e-02, 7.81215519e-01, 7.53886939e-01, 4.17970118e-01,
#          2.39702601e-01, 9.75140719e-01, 8.65500527e-01],
#         [5.07538801e-03, 1.18211614e-01, 4.83129394e-01, 3.84457768e-01,
#          6.47955909e-01, 2.40478952e-01, 9.42708834e-02],
#         [9.78498795e-01, 3.44252175e-01, 1.65565826e-01, 2.89824429e-01,
#          9.02440096e-02, 7.81448127e-01, 5.98762721e-01]],
#
#        [[6.31834926e-02, 1.47081542e-01, 5.40792542e-01, 8.22719442e-01,
#          6.55541679e-01, 7.55821203e-02, 6.31672543e-01],
#         [9.49066390e-01, 4.11011912e-03, 6.07006503e-01, 2.41123997e-01,
#          5.20195200e-01, 3.09845312e-01, 5.68171534e-02],
#         [7.50151209e-01, 9.38509740e-01, 9.38707324e-01, 1.22621227e-02,
#          6.22654811e-04, 6.76197666e-01, 4.66319840e-01]],
#
